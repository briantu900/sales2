# %%
import pandas as pd
df_sales = pd.read_csv('sales.csv',index_col=[0,1]) #the first 2 columns are set as index
df_sales.info() #info about dataframe including missing values and data types
#df_sales.isnull().sum() another way to check for missing values
#df_sales.dtypes another way of getting data types
# Out:
# <class 'pandas.core.frame.DataFrame'>
# MultiIndex: 23 entries, ('Africa', 'Western Africa') to ('USCA', 'Canada')
# Data columns (total 3 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   No_of_Orders  23 non-null     int64
#  1   Profit        23 non-null     object
#  2   Sales         23 non-null     object
# dtypes: int64(1), object(2)
# memory usage: 1.6+ KB

# %%
#first 3 rows
df_sales.head(3)
# Out:
#                         No_of_Orders      Profit      Sales
# Market Region
# Africa Western Africa            251  -12,901.51  78,476.06
#        Southern Africa            85   11,768.58  51,319.50
#        North Africa              182   21,643.08  86,698.89

# %%
#last 3 rows
df_sales.tail(3)
# Out:
#                    No_of_Orders     Profit       Sales
# Market Region
# USCA   Eastern US           443  47,462.04  264,973.98
#        Central US           356  33,697.43  170,416.31
#        Canada                49   7,246.62   26,298.81

# %%
#statistical info
#df_sales["Profit"] = df_sales["Profit"].str.replace(",","").astype(float)
df_sales.describe()
# Out:
#        No_of_Orders        Profit          Sales
# count     23.000000     23.000000      23.000000
# mean     366.478261  28859.944783  206285.108696
# std      246.590361  27701.193773  160589.886606
# min       37.000000 -16766.900000    8190.740000
# 25%      211.500000  12073.085000   82587.475000
# 50%      356.000000  20948.840000  170416.310000
# 75%      479.500000  45882.845000  290182.375000
# max      964.000000  82091.270000  656637.140000

# %%
#display sales column as series
df_sales['Sales']
# Out:
# Market        Region
# Africa        Western Africa        78,476.06
#               Southern Africa       51,319.50
#               North Africa          86,698.89
#               Eastern Africa        44,182.60
#               Central Africa        61,689.99
# Asia Pacific  Western Asia         124,312.24
#               Southern Asia        351,806.60
#               Southeastern Asia    329,751.38
#               Oceania              408,002.98
#               Eastern Asia         315,390.77
#               Central Asia           8,190.74
# Europe        Western Europe       656,637.14
#               Southern Europe      215,703.93
#               Northern Europe      252,969.09
#               Eastern Europe       108,258.93
# LATAM         South America        210,710.49
#               Central America      461,670.28
#               Caribbean            116,333.05
# USCA          Western US           251,991.83
#               Southern US          148,771.91
# ...

# %%
#display sales and profit columns as dataframe
df_sales.loc[:,['Sales','Profit']]
# Out:
#                                      Sales      Profit
# Market       Region
# Africa       Western Africa      78,476.06  -12,901.51
#              Southern Africa     51,319.50   11,768.58
#              North Africa        86,698.89   21,643.08
#              Eastern Africa      44,182.60    8,013.04
#              Central Africa      61,689.99   15,606.30
# Asia Pacific Western Asia       124,312.24  -16,766.90
#              Southern Asia      351,806.60   67,998.76
#              Southeastern Asia  329,751.38   20,948.84
#              Oceania            408,002.98   54,734.02
#              Eastern Asia       315,390.77   72,805.10
#              Central Asia         8,190.74   -2,649.76
# Europe       Western Europe     656,637.14   82,091.27
#              Southern Europe    215,703.93   18,911.49
#              Northern Europe    252,969.09   43,237.44
#              Eastern Europe     108,258.93   25,050.69
# LATAM        South America      210,710.49   12,377.59
# ...

# %%
#display data for southern asia
#df_sales.iloc[6]
df_sales.loc[('Asia Pacific', 'Southern Asia')]
# Out:
# No_of_Orders       469.00
# Profit           67998.76
# Sales           351806.60
# Name: (Asia Pacific, Southern Asia), dtype: float64

# %%
#display sales and profit for west, south and north africa
#df_sales.iloc[0:3,1:3]
df_sales.loc[[('Africa', 'Western Africa'),('Africa', 'Southern Africa'),('Africa', 'North Africa')],['Sales','Profit']]
#africa_data = df_sales.loc[('Africa',['Western Africa','Southern Africa','North Africa']), ['Profit', 'Sales']]
#africa_data
# Out:
#                            Sales    Profit
# Market Region
# Africa Western Africa   78476.06 -12901.51
#        Southern Africa  51319.50  11768.58
#        North Africa     86698.89  21643.08

# %%
#display markets with sales above 300,000
#df_sales["Sales"] = df_sales["Sales"].str.replace(",","").astype(float)
market_sales = df_sales.groupby('Market')['Sales'].sum().to_frame()
market_sales[market_sales['Sales'] > 300000]
# Out:
#                    Sales
# Market
# Africa         322367.04
# Asia Pacific  1537454.71
# Europe        1233569.09
# LATAM          788713.82
# USCA           862452.84
